# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [1,2,3]
y= [4,5,6]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# ## Pyplot API

# %% [markdown]
# Univariate variable - Focuses of only one variable at a time. It could be height, weight, or a category like yes or no.

# %% [markdown]
# Numerical

# %%
data = {
  "Salary" : [12400, 34000,78000,98700,67000,98000,45000,88000]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Salary
# 0   12400
# 1   34000
# 2   78000
# 3   98700
# 4   67000

# %%
import matplotlib.pyplot as plt

subjects = ["Python", "SQL", "Excel", "Power BI"]
students = [40, 35, 45, 30]

plt.bar(subjects, students)

plt.title("Students in Different Subjects")
plt.xlabel("Subjects")
plt.ylabel("Number of Students")

plt.show()

# %%
import matplotlib.pyplot as plt

subjects = ["Python", "SQL", "Excel", "Power BI"]
students = [40, 35, 45, 30]

plt.pie(students, labels=subjects, autopct="%1.1f%%")

plt.title("Subject-wise Distribution")

plt.show()

# %%
import matplotlib.pyplot as plt

x = range(-5, 6)
y = [i**2 for i in x]

plt.plot(x, y, marker="o")

plt.title("Graph of y = x²")
plt.xlabel("x")
plt.ylabel("y")

plt.grid()
plt.show()
